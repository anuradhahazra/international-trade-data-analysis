# %%
import pandas as pd

df = pd.read_csv("../data/raw/import_data_2017_2025.csv")

df.head()
# Out:
#   PORT CODE        DATE        IEC   HS CODE  \
# 0    INNSA1  2025-10-28  301049751  73239990
# 1    INNSA1  2025-10-28  301049751  73231000
# 2    INNSA1  2025-10-23  301049751  73239990
# 3    INNSA1  2025-10-13  301049751  73239990
# 4    INNSA1  2025-10-13  301049751  73239990
#
#                                    GOODS DESCRIPTION  Master category  \
# 0  TH5170 STEEL CUTLERY HOLDER (QTY:600 PCS/USD 2...              NaN
# 1  8001-2 STEEL SCRUBBER 2PCS SET (QTY: 336000 SE...              NaN
# 2  MILD STEEL MULTI FUNCTION CLOTH STAND (RYX-02-...              NaN
# 3  SB-12 STEEL TEA STRAINER BIG (QTY 6336 PCS/USD...              NaN
# 4  SB-12 STEEL TEA STRAINER BIG (QTY 43038 PCS/US...              NaN
#
#    Model Name  Model Number  Capacity  Qty  Unit of measure  Price  \
# 0         NaN           NaN       NaN  NaN              NaN    NaN
# 1         NaN           NaN       NaN  NaN              NaN    NaN
# ...

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.columns
# Out:
# Index(['PORT CODE', 'DATE', 'IEC', 'HS CODE', 'GOODS DESCRIPTION',
#        'Master category', 'Model Name', 'Model Number', 'Capacity', 'Qty',
#        'Unit of measure', 'Price', 'Unit of measure.1', 'QUANTITY', 'UNIT',
#        'UNIT PRICE_INR', 'TOTAL VALUE_INR', 'UNIT PRICE_USD',
#        'TOTAL VALUE_USD', 'DUTY PAID_INR'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PORT CODE          2079 non-null   object
#  1   DATE               2079 non-null   datetime64[ns]
#  2   IEC                2079 non-null   int64
#  3   HS CODE            2079 non-null   int64
#  4   GOODS DESCRIPTION  2079 non-null   object
#  5   Master category    0 non-null      float64
#  6   Model Name         0 non-null      float64
#  7   Model Number       0 non-null      float64
#  8   Capacity           0 non-null      float64
#  9   Qty                0 non-null      float64
#  10  Unit of measure    0 non-null      float64
#  11  Price              0 non-null      float64
#  12  Unit of measure.1  0 non-null      float64
#  13  QUANTITY           2079 non-null   float64
#  14  UNIT               2079 non-null   object
# ...

# %%
df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')
df['DATE'].head()
# Out:
# 0   2025-10-28
# 1   2025-10-28
# 2   2025-10-23
# 3   2025-10-13
# 4   2025-10-13
# Name: DATE, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PORT CODE          2079 non-null   object
#  1   DATE               2079 non-null   datetime64[ns]
#  2   IEC                2079 non-null   int64
#  3   HS CODE            2079 non-null   int64
#  4   GOODS DESCRIPTION  2079 non-null   object
#  5   Master category    0 non-null      float64
#  6   Model Name         0 non-null      float64
#  7   Model Number       0 non-null      float64
#  8   Capacity           0 non-null      float64
#  9   Qty                0 non-null      float64
#  10  Unit of measure    0 non-null      float64
#  11  Price              0 non-null      float64
#  12  Unit of measure.1  0 non-null      float64
#  13  QUANTITY           2079 non-null   float64
#  14  UNIT               2079 non-null   object
# ...

# %%
df['DATE'].dt.year.unique()
# Out:
# array([2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017], dtype=int32)

# %%
df['GOODS DESCRIPTION'].head(10)
# Out:
# 0    TH5170 STEEL CUTLERY HOLDER (QTY:600 PCS/USD 2...
# 1    8001-2 STEEL SCRUBBER 2PCS SET (QTY: 336000 SE...
# 2    MILD STEEL MULTI FUNCTION CLOTH STAND (RYX-02-...
# 3    SB-12 STEEL TEA STRAINER BIG (QTY 6336 PCS/USD...
# 4    SB-12 STEEL TEA STRAINER BIG (QTY 43038 PCS/US...
# 5    STEEL HANGER WITH HOOK (SL-89) (QTY:70056 PCS/...
# 6    STEEL HANGER 10PCS SET (AM-969) (QTY: 480 SET/...
# 7    AM-967 STEEL FRUIT BASKET (QTY 400 PCS/USD 1.0...
# 8    AM-966 STEEL FRUIT BASKET (QTY 400 PCS/USD 1.0...
# 9    AM-965 STEEL SPOON & FORK HOLDER (QTY 480 PCS/...
# Name: GOODS DESCRIPTION, dtype: object

# %%
df['UNIT'].unique()
# Out:
# array(['KGS', 'NOS', 'PCS', 'KGS ', 'KG', 'SET'], dtype=object)

# %%
df.isnull().sum()
# Out:
# PORT CODE               0
# DATE                    0
# IEC                     0
# HS CODE                 0
# GOODS DESCRIPTION       0
# Master category      2079
# Model Name           2079
# Model Number         2079
# Capacity             2079
# Qty                  2079
# Unit of measure      2079
# Price                2079
# Unit of measure.1    2079
# QUANTITY                0
# UNIT                    0
# UNIT PRICE_INR          0
# TOTAL VALUE_INR         0
# UNIT PRICE_USD          0
# TOTAL VALUE_USD         0
# DUTY PAID_INR           0
# dtype: int64

# %%
df[['DUTY PAID_INR', 'TOTAL VALUE_INR']].describe()
# Out:
#        DUTY PAID_INR  TOTAL VALUE_INR
# count   2.079000e+03     2.079000e+03
# mean    6.878388e+05     2.017286e+06
# std     6.223662e+05     1.694160e+06
# min     0.000000e+00     1.882250e+03
# 25%     2.092378e+05     7.717038e+05
# 50%     5.411963e+05     1.648069e+06
# 75%     9.742361e+05     2.838890e+06
# max     4.870250e+06     1.329217e+07
