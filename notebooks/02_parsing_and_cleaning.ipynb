# %%
import pandas as pd

# %%
def load_data(path):
    return pd.read_csv(path)

def clean_dates(df):
    return df

def handle_missing(df):
    return df

# %%
def clean_dates(df):
    df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')

    df['Year'] = df['DATE'].dt.year
    df['Month'] = df['DATE'].dt.month
    df['Quarter'] = df['DATE'].dt.quarter

    return df

# %%
df[['TOTAL VALUE_INR', 'DUTY PAID_INR', 'QUANTITY']].isna().sum()
# Out:
# TOTAL VALUE_INR    0
# DUTY PAID_INR      0
# QUANTITY           0
# dtype: int64

# %%
print("No missing values in key financial columns.")
# Out:
# No missing values in key financial columns.

# %%
import pandas as pd

df = pd.read_csv("../data/processed/trade_cleaned.csv")
print(df.columns)  # check column names
#print(df.columns.duplicated())
# Out:
# Index(['PORT CODE', 'DATE', 'IEC', 'HS CODE', 'GOODS DESCRIPTION',
#        'Master category', 'Model Name', 'Model Number', 'Capacity', 'Qty',
#        'Unit of measure', 'Price', 'Unit of measure.1', 'QUANTITY', 'UNIT',
#        'UNIT PRICE_INR', 'TOTAL VALUE_INR', 'UNIT PRICE_USD',
#        'TOTAL VALUE_USD', 'DUTY PAID_INR', 'Year', 'Month', 'Quarter',
#        'Date_of_Shipment', 'Model_Name_Parsed', 'Model_Number_Parsed',
#        'Capacity_Parsed', 'Material_Type_Parsed', 'Embedded_Quantity_Parsed',
#        'Unit_Price_USD_Parsed', 'Model_Name_Final', 'Model_Number_Final',
#        'Capacity_Final', 'Grand_Total_INR', 'Category', 'Sub_Category'],
#       dtype='object')

# %%
print(df.columns.duplicated())
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False]
